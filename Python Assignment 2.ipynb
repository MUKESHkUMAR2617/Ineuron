# %% [markdown]
#  **Assignment 2**

# %%
"""
Q.1 Create the below pattern using nested for loop in Python.

*
* *
* * *
* * * *
* * * * *
* * * *
* * *
* *
* 
"""

for i in range (0,9):
  if i<=4:
    for j in range(0,i+1):
        print('*',end = '')
    print('\n')
  else:
      for j in range(i,9):
          print('*',end ='')
      print('\n')
# Out:
# *
#
# **
#
# ***
#
# ****
#
# *****
#
# ****
#
# ***
#
# **
#
# *

# %%
'''Write a Python program to reverse a word afWrite a Python program to reverse a word after accepting the input from the user.ter accepting the input from the user.
Q.3 Write a Python program to reverse a word after accepting the input from the user.

'''

x=input("enter your text here:-")
print("text in reverse order are:-",x[::-1])
# Out:
# enter your text here:-mukesh kumar
# text in reverse order are:- ramuk hsekum
